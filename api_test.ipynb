# %%
import requests

url = "https://odds-api1.p.rapidapi.com/surebets"

querystring = {"oddsFormat":"decimal"}

headers = {
	"x-rapidapi-key": "365e3f0103mshc0c108ca0b9dc77p1bcd4djsn7eb58d2f8356",
	"x-rapidapi-host": "odds-api1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'0': {'betradarId': '52537157.0', 'date': '2024-11-29', 'eventId': 'id110013252537157', 'markets': {}, 'participant1': 'Atlanta Hawks', 'participant2': 'Cleveland Cavaliers', 'startTime': 1732909200.0, 'time': '19:40:00', 'tournamentId': 132}, '1': {'betradarId': '50128573.0', 'date': '2024-11-29', 'eventId': 'id140003150128573', 'markets': {}, 'participant1': 'Kansas City Chiefs', 'participant2': 'Las Vegas Raiders', 'startTime': 1732910400.0, 'time': '20:00:00', 'tournamentId': 31}, '2': {'betradarId': '52537127.0', 'date': '2024-11-30', 'eventId': 'id110013252537127', 'markets': {}, 'participant1': 'Chicago Bulls', 'participant2': 'Boston Celtics', 'startTime': 1732929000.0, 'time': '01:10:00', 'tournamentId': 132}, '3': {'betradarId': '52537123.0', 'date': '2024-11-29', 'eventId': 'id110013252537123', 'markets': {}, 'participant1': 'Memphis Grizzlies', 'participant2': 'New Orleans Pelicans', 'startTime': 1732918200.0, 'time': '22:10:00', 'tournamentId': 132}, '4': {'betradarId':
# ...

# %%
response.json()
# Out:
# {'0': {'betradarId': '52537157.0',
#   'date': '2024-11-29',
#   'eventId': 'id110013252537157',
#   'markets': {},
#   'participant1': 'Atlanta Hawks',
#   'participant2': 'Cleveland Cavaliers',
#   'startTime': 1732909200.0,
#   'time': '19:40:00',
#   'tournamentId': 132},
#  '1': {'betradarId': '50128573.0',
#   'date': '2024-11-29',
#   'eventId': 'id140003150128573',
#   'markets': {},
#   'participant1': 'Kansas City Chiefs',
#   'participant2': 'Las Vegas Raiders',
#   'startTime': 1732910400.0,
#   'time': '20:00:00',
#   'tournamentId': 31},
#  '2': {'betradarId': '52537127.0',
#   'date': '2024-11-30',
#   'eventId': 'id110013252537127',
#   'markets': {},
#   'participant1': 'Chicago Bulls',
#   'participant2': 'Boston Celtics',
#   'startTime': 1732929000.0,
#   'time': '01:10:00',
#   'tournamentId': 132},
#  '3': {'betradarId': '52537123.0',
#   'date': '2024-11-29',
#   'eventId': 'id110013252537123',
#   'markets': {},
#   'participant1': 'Memphis Grizzlies',
# ...
