# %%
import pandas as pd
import numpy as np
import unicodedata

# %%
census_data = pd.read_csv("census_demographic_data.csv")
vaccination_data = pd.read_csv("us_state_vaccinations.csv")
death_data = pd.read_csv("covid_death_data.csv")

# %%
census_data
# Out:
#                              Label (Grouping) Alabama!!Estimate  \
# 0                                 SEX AND AGE               NaN
# 1                            Total population         5,039,877
# 2                                        Male         2,445,896
# 3                                      Female         2,593,981
# 4           Sex ratio (males per 100 females)              94.3
# ..                                        ...               ...
# 89                        Total housing units         2,313,616
# 90             CITIZEN, VOTING AGE POPULATION               NaN
# 91            Citizen, 18 and over population         3,829,788
# 92                                       Male         1,827,345
# 93                                     Female         2,002,443
#
#    Alabama!!Margin of Error Alabama!!Percent Alabama!!Percent Margin of Error  \
# 0                       NaN              NaN                              NaN
# ...

# %%
labels_to_keep = [
    "Under 5 years",
    "5 to 9 years",
    "10 to 14 years",
    "15 to 19 years",
    "20 to 24 years",
    "25 to 34 years",
    "35 to 44 years",
    "45 to 54 years",
    "55 to 59 years",
    "60 to 64 years",
    "65 to 74 years",
    "75 to 84 years",
    "85 years and over",
    "White",
    "Black or African American",
    "American Indian and Alaska Native",
    "Asian",
    "Native Hawaiian and Other Pacific Islander",
    "Some other race",
]

# %%
column_selection = [census_data.columns[0]] + list(census_data.filter(like="Estimate").columns)

# %%
for i in census_data["Label (Grouping)"]:
unicodedata.normalize("NFKD", census_data["Label (Grouping)"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 unicodedata.normalize("NFKD", list(census_data["Label (Grouping)"]))
#
# TypeError: normalize() argument 2 must be str, not list

# %%
census_data["Label (Grouping)"].unique()
# Out:
# array(['SEX AND AGE', '\xa0\xa0\xa0\xa0Total population',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Male',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Female',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Sex ratio (males per 100 females)',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Under 5 years',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa05 to 9 years',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa010 to 14 years',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa015 to 19 years',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa020 to 24 years',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa025 to 34 years',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa035 to 44 years',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa045 to 54 years',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa055 to 59 years',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa060 to 64 years',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa065 to 74 years',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa075 to 84 years',
# ...
