# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
dataset_path = Path(Path.cwd().parent.parent.parent.parent, "Johns Hopkins/Data Engineering Final Project Group 5 - Documents/General/Final Project Datasets")

census_data = pd.read_csv(dataset_path/"demographic_data.csv")
vaccination_data = pd.read_csv(dataset_path/"us_state_vaccinations_data.csv")
death_data = pd.read_csv(dataset_path/"covid19_death_data.csv")

# %%
census_data
# Out:
#                              Label (Grouping) Alabama!!Estimate  \
# 0                                 SEX AND AGE               NaN
# 1                            Total population         5,039,877
# 2                                        Male         2,445,896
# 3                                      Female         2,593,981
# 4           Sex ratio (males per 100 females)              94.3
# ..                                        ...               ...
# 89                        Total housing units         2,313,616
# 90             CITIZEN, VOTING AGE POPULATION               NaN
# 91            Citizen, 18 and over population         3,829,788
# 92                                       Male         1,827,345
# 93                                     Female         2,002,443
#
#    Alabama!!Percent Alaska!!Estimate Alaska!!Percent Arizona!!Estimate  \
# 0               NaN              NaN             NaN               NaN
# 1         5,039,877          732,673         732,673         7,276,316
# 2             48.5%          383,121           52.3%         3,629,620
# 3             51.5%          349,552           47.7%         3,646,696
# 4               (X)            109.6             (X)              99.5
# ..              ...              ...             ...               ...
# 89              (X)          327,889             (X)         3,138,685
# 90              NaN              NaN             NaN               NaN
# 91        3,829,788          533,852         533,852         5,216,518
# 92            47.7%          281,367           52.7%         2,584,180
# 93            52.3%          252,485           47.3%         2,632,338
#
#    Arizona!!Percent Arkansas!!Estimate Arkansas!!Percent California!!Estimate  \
# 0               NaN                NaN               NaN                  NaN
# 1         7,276,316          3,025,891         3,025,891           39,237,836
# 2             49.9%          1,493,681             49.4%           19,618,934
# 3             50.1%          1,532,210             50.6%           19,618,902
# 4               (X)               97.5               (X)                100.0
# ..              ...                ...               ...                  ...
# 89              (X)          1,380,768               (X)           14,512,149
# 90              NaN                NaN               NaN                  NaN
# 91        5,216,518          2,237,649         2,237,649           26,028,290
# 92            49.5%          1,085,739             48.5%           12,858,732
# 93            50.5%          1,151,910             51.5%           13,169,558
#
#     ... Washington!!Estimate Washington!!Percent West Virginia!!Estimate  \
# 0   ...                  NaN                 NaN                     NaN
# 1   ...            7,738,692           7,738,692               1,782,959
# 2   ...            3,897,320               50.4%                 887,360
# 3   ...            3,841,372               49.6%                 895,599
# 4   ...                101.5                 (X)                    99.1
# ..  ...                  ...                 ...                     ...
# 89  ...            3,257,140                 (X)                 858,462
# 90  ...                  NaN                 NaN                     NaN
# 91  ...            5,529,508           5,529,508               1,408,767
# 92  ...            2,766,294               50.0%                 694,950
# 93  ...            2,763,214               50.0%                 713,817
#
#    West Virginia!!Percent Wisconsin!!Estimate Wisconsin!!Percent  \
# 0                     NaN                 NaN                NaN
# 1               1,782,959           5,895,908          5,895,908
# 2                   49.8%           2,955,249              50.1%
# 3                   50.2%           2,940,659              49.9%
# 4                     (X)               100.5                (X)
# ..                    ...                 ...                ...
# 89                    (X)           2,748,274                (X)
# 90                    NaN                 NaN                NaN
# 91              1,408,767           4,480,576          4,480,576
# 92                  49.3%           2,226,041              49.7%
# 93                  50.7%           2,254,535              50.3%
#
#    Wyoming!!Estimate Wyoming!!Percent Puerto Rico!!Estimate  \
# 0                NaN              NaN                   NaN
# 1            578,803          578,803             3,263,584
# 2            296,007            51.1%             1,543,991
# 3            282,796            48.9%             1,719,593
# 4              104.7              (X)                  89.8
# ..               ...              ...                   ...
# 89           274,373              (X)             1,526,801
# 90               NaN              NaN                   NaN
# 91           436,049          436,049             2,674,230
# 92           221,939            50.9%             1,246,100
# 93           214,110            49.1%             1,428,130
#
#    Puerto Rico!!Percent
# 0                   NaN
# 1             3,263,584
# 2                 47.3%
# 3                 52.7%
# 4                   (X)
# ..                  ...
# 89                  (X)
# 90                  NaN
# 91            2,674,230
# 92                46.6%
# 93                53.4%
#
# [94 rows x 105 columns]

# %%
labels_to_keep = [
    "Male",
    "Female",
    "Under 5 years",
    "5 to 9 years",
    "10 to 14 years",
    "15 to 19 years",
    "20 to 24 years",
    "25 to 34 years",
    "35 to 44 years",
    "45 to 54 years",
    "55 to 59 years",
    "60 to 64 years",
    "65 to 74 years",
    "75 to 84 years",
    "85 years and over",
    "White",
    "Black or African American",
    "American Indian and Alaska Native",
    "Asian",
    "Native Hawaiian and Other Pacific Islander",
    "Some other race",
    "White and Black or African American",
    "White and American Indian and Alaska Native",
    "White and Asian",
    "Black or African American and American Indian and Alaska Native",

]

# %%
column_selection = [census_data.columns[0]] + list(census_data.filter(like="Estimate").columns)

# %%
census_data["Label (Grouping)"][2].strip()
# Out:
# 'Male'

# %%
row_labels = [i.strip() for i in census_data["Label (Grouping)"]]
census_data["Label (Grouping)"] = row_labels

# %%
census_data_filtered = census_data.drop_duplicates(subset="Label (Grouping)")
census_data_filtered = census_data_filtered.loc[census_data_filtered.isin(labels_to_keep).iloc[:,0]]

# %%
census_data_melted = census_data_filtered.melt(id_vars="Label (Grouping)", var_name="State", value_name="Population")
stripped = [i.replace("!!Estimate", "") for i in census_data_melted["State"]]

# %%
stripped
# Out:
# ['Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alabama!!Percent',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Alaska!!Percent',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arizona!!Percent',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'Arkansas!!Percent',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California!!Percent',
#  'California!!Percent',
#  'California!!Percent',
#  'California!!Percent',
#  'California!!Percent',
#  'California!!Percent',
#  'California!!Percent',
#  'California!!Percent',
#  'California!!Percent',
#  'California!!Percent',
#  'California!!Percent',
#  'California!!Percent',
#  'California!!Percent',
#  'California!!Percent',
#  'California!!Percent',
#  'California!!Percent',
#  'California!!Percent',
#  'California!!Percent',
#  'California!!Percent',
#  'California!!Percent',
#  'California!!Percent',
#  'California!!Percent',
#  'California!!Percent',
#  'California!!Percent',
#  'California!!Percent',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Colorado!!Percent',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Connecticut!!Percent',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'Delaware!!Percent',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'District of Columbia!!Percent',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Florida!!Percent',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Georgia!!Percent',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Hawaii!!Percent',
#  'Idaho',
#  'Idaho',
#  'Idaho',
#  'Idaho',
#  'Idaho',
#  'Idaho',
#  'Idaho',
#  'Idaho',
#  'Idaho',
#  'Idaho',
#  'Idaho',
#  'Idaho',
#  'Idaho',
#  'Idaho',
#  'Idaho',
#  'Idaho',
#  'Idaho',
#  'Idaho',
#  'Idaho',
#  'Idaho',
#  'Idaho',
#  'Idaho',
#  'Idaho',
#  'Idaho',
#  'Idaho',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Idaho!!Percent',
#  'Illinois',
#  'Illinois',
#  'Illinois',
#  'Illinois',
#  'Illinois',
#  'Illinois',
#  'Illinois',
#  'Illinois',
#  'Illinois',
#  'Illinois',
#  'Illinois',
#  'Illinois',
#  'Illinois',
#  'Illinois',
#  'Illinois',
#  'Illinois',
#  'Illinois',
#  'Illinois',
#  'Illinois',
#  'Illinois',
#  'Illinois',
#  'Illinois',
#  'Illinois',
#  'Illinois',
#  'Illinois',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Illinois!!Percent',
#  'Indiana',
#  'Indiana',
#  'Indiana',
#  'Indiana',
#  'Indiana',
#  'Indiana',
#  'Indiana',
#  'Indiana',
#  'Indiana',
#  'Indiana',
#  'Indiana',
#  'Indiana',
#  'Indiana',
#  'Indiana',
#  'Indiana',
#  'Indiana',
#  'Indiana',
#  'Indiana',
#  'Indiana',
#  'Indiana',
#  'Indiana',
#  'Indiana',
#  'Indiana',
#  'Indiana',
#  'Indiana',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Indiana!!Percent',
#  'Iowa',
#  'Iowa',
#  'Iowa',
#  'Iowa',
#  'Iowa',
#  'Iowa',
#  'Iowa',
#  'Iowa',
#  'Iowa',
#  'Iowa',
#  'Iowa',
#  'Iowa',
#  'Iowa',
#  'Iowa',
#  'Iowa',
#  'Iowa',
#  'Iowa',
#  'Iowa',
#  'Iowa',
#  'Iowa',
#  'Iowa',
#  'Iowa',
#  'Iowa',
#  'Iowa',
#  'Iowa',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Iowa!!Percent',
#  'Kansas',
#  'Kansas',
#  'Kansas',
#  'Kansas',
#  'Kansas',
#  'Kansas',
#  'Kansas',
#  'Kansas',
#  'Kansas',
#  'Kansas',
#  'Kansas',
#  'Kansas',
#  'Kansas',
#  'Kansas',
#  'Kansas',
#  'Kansas',
#  'Kansas',
#  'Kansas',
#  'Kansas',
#  'Kansas',
#  'Kansas',
#  'Kansas',
#  'Kansas',
#  'Kansas',
#  'Kansas',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kansas!!Percent',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Kentucky!!Percent',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Louisiana!!Percent',
#  'Maine',
#  'Maine',
#  'Maine',
#  'Maine',
#  'Maine',
#  'Maine',
#  'Maine',
#  'Maine',
#  'Maine',
#  'Maine',
#  'Maine',
#  'Maine',
#  'Maine',
#  'Maine',
#  'Maine',
#  'Maine',
#  'Maine',
#  'Maine',
#  'Maine',
#  'Maine',
#  'Maine',
#  'Maine',
#  'Maine',
#  'Maine',
#  'Maine',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  'Maine!!Percent',
#  ...]
