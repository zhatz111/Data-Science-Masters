# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Lab 3 - Visualization

# %%
# %matplotlib inline

# %% [markdown]
# The special command above will make all the `matplotlib` images appear in the notebook.

# %% [markdown]
# ## General Instructions
#
# In this course, Labs are the chance to applying concepts and methods discussed in the module.
# They are a low stakes (pass/fail) opportunity for you to try your hand at *doing*.
# Please make sure you follow the general Lab instructions, described in the Syllabus.
# The summary is:
#
# * Discussions should start as students work through the material, first Wednesday at the start of the new Module week.
# * Labs are due by Sunday.
# * Lab solutions are released Monday.
# * Post Self Evaluation and Lab to Lab Group on Blackboard and Lab to Module on Blackboard on Monday.
#
# The last part is important because the Problem Sets will require you to perform the same or similar tasks without guidance.
# Problem Sets are your opportunity to demonstrate that you understand how to apply the concepts and methods discussed in the relevant Modules and Labs.

# %% [markdown]
# ## Specific Instructions
#
# 1.  For Blackboard submissions, if there are no accompanying files, you should submit *only* your notebook and it should be named using *only* your JHED id: fsmith79.ipynb for example if your JHED id were "fsmith79". If the assignment requires additional files, you should name the *folder/directory* your JHED id and put all items in that folder/directory, ZIP it up (only ZIP...no other compression), and submit it to Blackboard.
#
#     * do **not** use absolute paths in your notebooks. All resources should located in the same directory as the rest of your assignments.
#     * the directory **must** be named your JHED id and **only** your JHED id.
#     * do **not** return files provided by us (data files, .py files)
#
#
# 2. Data Science is as much about what you write (communicating) as the code you execute (researching). In many places, you will be required to execute code and discuss both the purpose and the result. Additionally, Data Science is about reproducibility and transparency. This includes good communication with your team and possibly with yourself. Therefore, you must show **all** work.
#
# 3. Avail yourself of the Markdown/Codecell nature of the notebook. If you don't know about Markdown, look it up. Your notebooks should not look like ransom notes. Don't make everything bold. Clearly indicate what question you are answering.
#
# 4. Submit a cleanly executed notebook. The first code cell should say `In [1]` and each successive code cell should increase by 1 throughout the notebook.
#
# **There are only 4 charts because we expect depth rather than breadth**

# %%
import numpy as np
import random as py_random
import numpy.random as np_random
import time
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

# %%
THEME = "darkslategray"

# %% [markdown]
# <div style="background: lemonchiffon; margin:20px; padding: 20px;">
#     <strong>Note</strong>
#     <p>Defining your main color in a variable makes it easier when your boss says, "can you make these all blue?".</p>
# </div>

# %% [markdown]
# ## Data Visualization
#
# Here are four (4) Charts we want you to analyze.
# There are only four charts because we want you to be thorough and, based on the materials from the Module, sophisticated in your analysis.
# You should not answer now nor on any future assignment, "because pie charts are bad" or "because we've been told not to use pie charts".
# Please make sure you check the Solution on Monday and compare it to your own.
#
# Some of these charts work as "infographics" but we want you to evaluate them as if they were slides to be presented to the CEO, that is, a data science presentation.
# (Those kinds of slides don't find their way onto Google).

# %% [markdown]
# ### Chart 1
#
# 1. What do you think the main story of the chart is? Does the chart really tell it? Identify any secondary stories.
# 2. Discuss how the chart either adheres to or violates the principles discussed in the module (Cleveland, Ware, and Gestalt).
# 3. Discuss at least two alternative charts that follow the guidelines presented in the module.
# 4. Create one of those alternatives by decoding the values as best you as you can and using `matplotlib` (you may use `seaborn` only to change the formatting).
#
# You may insert as many Markdown and Code cells below each chart as you need.

# %% [markdown]
# <img width="50%" src="data:image/jpeg;base64,..."/>

# %% [markdown]
# __Question 1__
#
# - The main story is that McDonald's dominates fast-food sales, much more than every other competitor with its $41 billion being more than the next several chains combined. The chart tries to drive this home by showing the size the McDonald's logo against the other chain's logos.
# - It only loosely tells a story. The visual message is the McDonald's logo overlaid on a y-axis, but the other brands' values are conveyed almost entirely by text labels, not by position or size. The reader isn't actually seeing the comparison, they're reading numbers and looking at logos placed at roughly arbitrary heights.
# - Secondary stories include the ranking of the remaining chains and the random comparison of McDonald's sales to the GDP of Afghanistan ($21B) in order to give it a sense of scale that is more so embellishment than actual useful content.
#
# __Question 2__
# - Cleveland: The chart completely fails the core lesson. Cleveland's ranking puts position along a common scale at the top and area/volume near the bottom for accuracy. This chart forces the reader onto the worst tasks: judging logo areas and reading detached text labels. The McDonald's value is encoded as the height/area of an logo graphic, while competitors are encoded as logos of inconsistent size sitting at inconsistent heights. There is no common baseline, so direct comparison is very difficult without reading every label.
# - Ware: Ware emphasizes minimal processing and not overloading the viewer. Here the Afghanistan map, the arches, the axis, and eight logos all compete for attention of the reader. Color does not help either, and the gridline axis (0–40) implies precision that the logos don't meet.
# - Gestalt: Leader lines connect labels to logos, signaling that the spatial layout itself carries no reliable meaning. There's no common region or alignment to group the competitors for comparison.
# - The arches act as a chart element whose area is not proportional to $41B in any consistent way relative to the other logos which inflates the dominance of that logo.
#
# __Question 3__
# - Horizontal bar chart: sorted descending by sales amount with a single common baseline and value labels at the end of each bar. This puts every company on a common scale and makes the ranking much more readable.
# - Dot plot: brands on the y-axis sorted by value, a single dot per brand on a shared x-axis. Equally accurate, and scales nicely if more brands are added.
#
# __Question 4__
# - See code below for horizontal bar chart.

# %%
data = {
    "Sales_x": [41.0, 11.3, 9.4, 8.2, 8.0, 4.3, 4.1],
    "Brand_y": ["McDonalds", "Burger King", "Wendy's", "KFC", "Pizza Hut", "Taco Bell", "Starbucks"]
}

# sort ascending so largest ends up on top in barh
pairs = sorted(zip(data["Sales_x"], data["Brand_y"]))
sales, brands = zip(*pairs)

plt.figure(figsize=(10, 6))
bars = plt.barh(brands, sales, color="steelblue")
plt.bar_label(bars, fmt='$%.1fB', padding=3, color=THEME)
plt.xlabel("Sales (in billions)", fontsize=14, color=THEME)
plt.ylabel("Brand", fontsize=14, color=THEME)
plt.title("Sales by Brand", fontsize=16, color=THEME)
plt.xlim(0, 46)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Chart 2
#
# 1. What do you think the main story of the chart is? Does the chart really tell it? Identify any secondary stories.
# 2. Discuss how the chart either adheres to or violates the principles discussed in the module (Cleveland, Ware, and Gestalt).
# 3. Discuss at least two alternative charts that follow the guidelines presented in the module.
# 4. Create one of those alternatives by decoding the values as best you as you can and using `matplotlib` (you may use `seaborn` only to change the formatting).
#
# You may insert as many Markdown and Code cells below each chart as you need.

# %% [markdown]
# <img width="750" src="data:image/jpeg;base64,..."/>

# %% [markdown]
# __Question 1__
#
# - The main story is that food imports have doubled in a decade and now make up roughly a fifth of what Americans eat. The main part of the graphic then makes the claim: certain food categories are heavily import dependent like seafood (88%), honey (61%), lamb (52%), fruit and nuts (51%) while others like fresh vegetables (20%) are much less so.
# - The chart does not tell the full story. The headline statistic, imports doubling over a decade, and the ~20% overall figure is never shown. There is no time series, no trend, or anything about doubled. The chart shows a snapshot of import share by category, which is a different story than the main one. The reader is told about a trend but never really shown it.
# - Secondary stories: the top exporter countries per category (Mexico 26% of fruit, Mexico 50% of vegetables, China 16% of seafood) is buried in a small table at the bottom and not connected to the percentages above.
# - The numbers are also not part of a whole. 88% + 61% + 52% + 51% + 20% does not sum to anything meaningful since each is an independent import share for a different category but the central visual is built like a pie/spiral, which falsely implies a summation of percentages.
#
# __Question 2__
# - Cleveland: This is the main failure. The percentages are representated by detached text labels and food photographs of different sizes, areas, and visual weights. Comparing a peach slice to a lamb to a shrimp tells you nothing about the percentages that they represent. The viewer is pushed onto photo size judgment when the data would be more comparable on a common positional scale. The onion in the middle isn't even a chart, it's something that reads as a pie chart, implying the slices partition a whole when they don't.
# - Ware: Huge attentional overload. Photorealistic food images dominate visual processing and the actual data is small gray text. Color carries no real meaning. This is considered high cognitive load with more fo the graphic spent on decoration rather than data.
# - Gestalt: Proximity is misused because the exporter table at the bottom is spatially separated from the categories it relates to, so "China 16%" doesn't connect to "Seafood 88%". There's no alignment or common region that would let the six category figures be grouped and ranked.
#
# __Question 3__
# - Sorted horizontal bar chart of import share by category: one bar per food category, common baseline at 0, sorted descending. This is the most accurate visualization and reads in one glance. A reference line at the 20% overall import average would connect it back to the headline.
# - Stacked bar of exporter share by category: for the secondary story, a small grouped bar chart showing each category's top two exporters, so the country comparisons sit on a common scale instead of in a floating table.
#
# __Question 4__
# - See code below for horizontal bar chart.

# %%
sns.set_theme(style="whitegrid")

data = {
    "Seafood": 88, "Honey": 61, "Lamb": 52,
    "Fruit and Nuts": 51, "Fresh Vegetables/Melons": 20,
}

pairs = sorted(data.items(), key=lambda kv: kv[1])
cats, vals = zip(*pairs)

fig, ax = plt.subplots(figsize=(9, 5))
bars = ax.barh(cats, vals, color=["#1f6f8b" if v >= 50 else "#9bbfc7" for v in vals])
ax.bar_label(bars, fmt='%d%%', padding=3)
ax.axvline(20, color="#c0392b", ls="--", lw=1.2)
ax.set_xlabel("Share of U.S. consumption that is imported (%)")
ax.set_title("How Import-Dependent Each Food Category Is", weight="bold")
ax.set_xlim(0, 100)
sns.despine(left=True, bottom=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Chart 3
#
# 1. What do you think the main story of the chart is? Does the chart really tell it? Identify any secondary stories.
# 2. Discuss how the chart either adheres to or violates the principles discussed in the module (Cleveland, Ware, and Gestalt).
# 3. Discuss at least two alternative charts that follow the guidelines presented in the module.
# 4. Create one of those alternatives by decoding the values as best you as you can and using `matplotlib` (you may use `seaborn` only to change the formatting).
#
# You may insert as many Markdown and Code cells below each chart as you need.

# %% [markdown]
# <img width="750" src="data:image/jpeg;base64,..."/>

# %% [markdown]
# __Question 1__
#
# - The main story is that the legal drinking age across Canada is almost entirely the same, 19 in every province except Alberta, Manitoba, and Quebec, where it's 18.
# - Does the chart tell this? Technically yes, but it hides the only thing that matters. Because the y-axis is truncated to start at 17, the difference between 18 and 19 is wildly exaggerated and a one-year difference looks like the 18 bars are roughly half the height of the 19 bars. The actual story is buried under bars that all look drastically different when they're really only one unit apart.
# - There's barely a secondary story here since the data is essentially a lookup table of 13 values that take one of two possibilities. The headline is about one jurisdiction, but the chart shows all 13, which is decent context.
#
# __Question 2__
# - Cleveland: The bars on a common baseline is actually a good choice with position/length on a common scale being the most accurate. The flaw is the truncated baseline, which messes up the proportionality Cleveland's length/judgment relies on. A bar chart's length is supposed to be readable as magnitude but the truncation makes 18 look like 50% of 19.
# - Ware: Heavy redundancy and clutter for almost no information. Thirteen bars, vertical rotated labels that are hard to read, and value labels on every bar. The chart spends enormous space and attention to convey what is essentially 10 are 19 and 3 are 18. The cognitive effort to extract the pattern is higher than the pattern deserves.
# - Gestalt: Similarity could have done the heavy lifting by coloring the 18s differently from the 19s. Instead all bars are the same blue, so the three 18 provinces don't pop as a group, you have to read each label. The truncated axis also breaks the good continuation expectation viewers bring to bar heights.
#
# __Question 3__
# - Bar chart with a zero baseline, with the two 18-provinces highlighted by color. Starting the axis at 0 shows the bars as nearly equal, while a contrasting color on Alberta/Manitoba/Quebec uses Gestalt similarity to make the exceptions instantly visible.
# - A small table or a simple categorical dot/grouped display with only two distinct values. A clean two-row table communicates faster than any chart. A grouped dot plot is the chart form of the same idea.
#
# __Question 4__
# - See code below for horizontal bar chart.

# %%
data = {
    "B.C.": 19, "Alberta": 18, "Sask.": 19, "Manitoba": 18,
    "Ontario": 19, "Quebec": 18, "N.B.": 19, "P.E.I.": 19,
    "N.S.": 19, "Nfld.": 19, "NWT": 19, "Nunavut": 19, "Yukon": 19,
}

places, ages = list(data.keys()), list(data.values())
colors = ["#c0392b" if a == 18 else "#2e75b6" for a in ages]

fig, ax = plt.subplots(figsize=(11, 5))
bars = ax.bar(places, ages, color=colors)
ax.bar_label(bars, fmt='%d', padding=3)
ax.set_ylim(0, 22)
ax.set_ylabel("Legal drinking age")
ax.set_title("Legal Drinking Age Across Canada: 19 Almost Everywhere", weight="bold")
ax.tick_params(axis="x", rotation=45)
sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Chart 4
# 1. What do you think the main story of the chart is? Does the chart really tell it? Identify any secondary stories.
# 2. Discuss how the chart either adheres to or violates the principles discussed in the module (Cleveland, Ware, and Gestalt).
# 3. Discuss at least two alternative charts that follow the guidelines presented in the module.
# 4. Create one of those alternatives by decoding the values as best you as you can and using `matplotlib` (you may use `seaborn` only to change the formatting).
#
# You may insert as many Markdown and Code cells below each chart as you need.

# %% [markdown]
# <img width="750" src="data:image/jpeg;base64,..."/>

# %% [markdown]
# __Question 1__
#
# - The intended story is the trajectory of the U.S. unemployment rate through 2011 under the Obama administration. The actual data is that it drifted from 9.0% in January up to a 9.2% peak in June, then came back down to 8.6% by November which is a roughly flat year with a modest decline of 0.4%.
# - Does the chart tell that story? It tells a distorted version. The main flaw is that the y-axis is broken/non-linear. It runs 8%, 8.5%, 9%, 9.5%, 10% but the November 8.6% point is plotted at nearly the same height as the 9.0% points, far above where 8.6% should sit. The data point that represents the biggest improvement (8.6%) is plotted almost level with the worst months, flattening the year-end drop so the line looks horizontal instead of decreasing. The visualization contradicts the numbers.
# - Secondary story: the small mid-year hump but its magnitude is overstated by the same scale problems.
#
# __Question 2__
# - Cleveland: A line/time-series on a common positional scale is the right encoding for trend data so the chart type is correct. Cleveland's accuracy depends on good faith position. Here position is corrupted, the 8.6% endpoint is plotted well above its true value. The result misrepresents the one comparison that matters (Nov vs Jan).
# - Ware: Heavy chart style drains attention from the data. The 3D beveled markers, red fill, glow, and decorative background all consume attention bandwidth while encoding nothing. The visual channels are spent on style, and the data ink ratio is poor.
# - Gestalt: Good continuation, the property that makes a line read as a trend is exactly what the broken axis messes up. The eye follows a near-flat line and sees no improvement which contradicts the decline. The line correctly uses connectedness to group the months as a sequence, which is the one Gestalt positive.
#
# __Question 3__
# - Line chart with a correct, linear y-axis, ideally anchored at 0 with minimal markers. This restores good continuation so the year-end dip is visible and the scale of month-to-month change is honest. A zero baseline shows how small the variation really is.
# - A clean dot plot of monthly values or one honest line chart.
#
# __Question 4__
# - See code below for horizontal bar chart.

# %%
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
          "Jul", "Aug", "Sep", "Oct", "Nov"]
rate = [9.0, 8.9, 8.8, 9.0, 9.1, 9.2, 9.1, 9.1, 9.1, 9.0, 8.6]

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(months, rate, marker="o", color="#c0392b", linewidth=2)
ax.set_ylim(0, 10)
ax.set_ylabel("Unemployment rate (%)")
ax.set_title("U.S. Unemployment Rate, 2011 (Source: BLS)", weight="bold")
sns.despine()
plt.tight_layout()
plt.show()
